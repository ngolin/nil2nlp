# %% [markdown]
# # 翻译器：从法文到英文
#
# > 原文：https://docs.pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html
#
# 本篇笔记用更简洁和现代的 API 重新实现原文的分类器，并提供更好的可读性和更好的性能。大幅简化了原文的代码架构和实现。

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

torch.manual_seed(9527)

# %% [markdown]
# ## 1. 数据理解
#
# `data/fra-eng.txt` 是个 txt 文件，文件内容每行为一对英法翻译，英文和法文以 `\t` 隔开，英法句子已提前分词，各分词以 ` ` 隔开。现把每行读出，分割出英法句子，统计词频，去除词频较低或句子较长的语料。

# %%
import jieba

class WordStat:
    def __init__(self, path):
        self.pairs, self.fra_w2c, self.eng_w2c = [], {}, {}
        with open(path, "r", encoding="utf-8") as f:
            for line in f:
                fra, eng = line.lower().strip().split("\t")
                fra, eng = fra.split(), eng.split()
                self.pairs.append((fra, eng))
                for word in fra:
                    self.fra_w2c[word] = self.fra_w2c.get(word, 0) + 1
                for word in eng:
                    self.eng_w2c[word] = self.eng_w2c.get(word, 0) + 1

    def take(self, min_count=1, max_length=10):

        fra_w2c, eng_w2c = dict(self.fra_w2c), dict(self.eng_w2c)

        def predicate(fra, eng):
            fra_map = map(lambda w: self.fra_w2c[w] > min_count, fra)
            eng_map = map(lambda w: self.eng_w2c[w] > min_count, eng)
            to_remove = (
                max(len(fra), len(eng)) > max_length
                or not all(fra_map)
                or not all(eng_map)
            )
            if to_remove:
                for word in fra:
                    fra_w2c[word] -= 1
                for word in eng:
                    eng_w2c[word] -= 1
            return not to_remove

        def sorted_words(w2c):
            sorted_item = sorted(w2c.items(), key=lambda wc: wc[1], reverse=True)
            return [w for w, c in sorted_item if c]

        fra_eng = [pair for pair in self.pairs if predicate(*pair)]

        return fra_eng, sorted_words(fra_w2c), sorted_words(eng_w2c)


pad, seq_len = 0, 12

fra_eng, fra_words, eng_words = WordStat("./data/fra-eng.txt").take(
    min_count=50, max_length=seq_len - 1
)


len(fra_eng), len(fra_words), len(eng_words)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/n8/p2f6qm3n7r17bcv_2chh5q_h0000gn/T/jieba.cache
# Loading model cost 0.234 seconds.
# Prefix dict has been built successfully.
# (40013, 1538, 1216)

# %% [markdown]
# ## 2. 模型设计

# %%
class Translator(nn.Module):
    def __init__(self, source_size, target_size, hidden_size, dropout=0.1):
        super().__init__()
        self.encoder = Encoder(source_size, hidden_size, dropout)
        self.decoder = Decoder(target_size, hidden_size, dropout)

    def forward(self, source_input, target_input=None):
        return self.decoder(self.encoder(source_input), target_input)


class Encoder(nn.Module):
    def __init__(self, source_size, hidden_size, dropout):
        super().__init__()
        self.emb = nn.Embedding(source_size, hidden_size)
        self.out = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)

    def forward(self, source_input):
        return self.gru(self.out(self.emb(source_input)))


class Decoder(nn.Module):
    def __init__(self, target_size, hidden_size, dropout):
        super().__init__()
        self.emb = nn.Embedding(target_size, hidden_size)
        self.out = nn.Dropout(dropout)
        self.att = Attention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.lin = nn.Linear(hidden_size, target_size, bias=False)

    def forward(self, encoded, target_input=None):
        encoder_output, hidden = encoded
        batch_size, seq_len, *_ = encoder_output.shape
        decoder_output = []
        input = torch.zeros(batch_size, 1, dtype=torch.int, device=device)
        for i in range(seq_len):
            output, hidden = self.step(input, hidden, encoder_output)
            decoder_output.append(output)
            if target_input is None:
                input = output.argmax(dim=-1).detach()
            else:
                input = target_input[:, i : i + 1]
        return torch.cat(decoder_output, dim=1)

    def step(self, decoder_input, hidden, encoder_output):
        embedded = self.out(self.emb(decoder_input))
        context = self.att(hidden.permute(1, 0, 2), encoder_output)
        output, hidden = self.gru(torch.cat([embedded, context], dim=-1), hidden)
        return self.lin(output), hidden


class Attention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.wa = nn.Linear(hidden_size, hidden_size)
        self.ua = nn.Linear(hidden_size, hidden_size)
        self.va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.va((self.wa(query) + self.ua(keys)).tanh())
        weights = scores.squeeze(2).unsqueeze(1).softmax(dim=-1)
        context = weights @ keys
        return context


if torch.accelerator.is_available():
    device = torch.accelerator.current_accelerator().type
else:
    device = "cpu"

source_size, target_size, hidden_size = len(fra_words) + 1, len(eng_words) + 1, 128

model = Translator(source_size, target_size, hidden_size).to(device)

model
# Out:
# Translator(
#   (encoder): Encoder(
#     (emb): Embedding(1539, 128, padding_idx=0)
#     (out): Dropout(p=0.1, inplace=False)
#     (gru): GRU(128, 128, batch_first=True)
#   )
#   (decoder): Decoder(
#     (emb): Embedding(1217, 128, padding_idx=0)
#     (out): Dropout(p=0.1, inplace=False)
#     (att): Attention(
#       (wa): Linear(in_features=128, out_features=128, bias=True)
#       (ua): Linear(in_features=128, out_features=128, bias=True)
#       (va): Linear(in_features=128, out_features=1, bias=True)
#     )
#     (gru): GRU(256, 128, batch_first=True)
#     (lin): Linear(in_features=128, out_features=469, bias=False)
#   )
# )

# %% [markdown]
# ## 3. 数据准备

# %%
from torch.utils.data import Dataset, DataLoader, random_split

class Dataset(Dataset):
    def __init__(self, fra_eng, fra_words, eng_words):
        self.data = []
        for fra, eng in fra_eng:
            x = [
                fra_words.index(fra[i]) + 1 if i < len(fra) else 0
                for i in range(seq_len)
            ]
            y = [
                eng_words.index(eng[i]) + 1 if i < len(eng) else 0
                for i in range(seq_len)
            ]
            self.data.append((torch.tensor(x), torch.tensor(y)))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]


batch_size, dataset = 32, Dataset(fra_eng, fra_words, eng_words)

train_data, test_data = random_split(dataset, [len(dataset) - batch_size, batch_size])

dataloader = DataLoader(train_data, batch_size, shuffle=True)

for source, target in dataloader:
    print(source.dtype, target.shape)
    break
# Out:
# torch.int64 torch.Size([32, 12])

# %% [markdown]
# ## 4. 模型训练
#
# 1. 损失函数用 nn.CrossEntropyLoss
# 2. 优化器用 optim.Adam

# %%
import torch.optim as optim

def train(model, dataloader, epochs=50, lr=1e-3):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn, losses = nn.CrossEntropyLoss(), []
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for source, target in dataloader:
            source, target = source.to(device), target.to(device)
            output = model(source, target)
            loss = loss_fn(output.view(-1, output.size(-1)), target.view(-1))

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            loss = loss.cpu().item()
            losses.append(loss)
            total_loss += loss
        print(f"Epoch {epoch+1:>2}/{epochs}, Loss: {total_loss / len(dataloader)}")
    return losses


losses = train(model, dataloader)

plt.figure()
plt.plot(losses)
plt.show()
# Out:
# Epoch  1/50, Loss: 1.9887562544449515
# Epoch  2/50, Loss: 1.3165669366069461
# Epoch  3/50, Loss: 1.079955942216127
# Epoch  4/50, Loss: 0.9107967519241831
# Epoch  5/50, Loss: 0.7589456371639086
# Epoch  6/50, Loss: 0.646041426062584
# Epoch  7/50, Loss: 0.5674716377387876
# Epoch  8/50, Loss: 0.5194134502307228
# Epoch  9/50, Loss: 0.5051235760035722
# Epoch 10/50, Loss: 0.4629231195087018
# Epoch 11/50, Loss: 0.4336867011111716
# Epoch 12/50, Loss: 0.39471622041386106
# Epoch 13/50, Loss: 0.3778433955557968
# Epoch 14/50, Loss: 0.3905049510948036
# Epoch 15/50, Loss: 0.35865498531771745
# Epoch 16/50, Loss: 0.33132549052977045
# Epoch 17/50, Loss: 0.30019385302844254
# Epoch 18/50, Loss: 0.2924215212788271
# Epoch 19/50, Loss: 0.2852359208399835
# Epoch 20/50, Loss: 0.2724785956027715
# Epoch 21/50, Loss: 0.2465181002798288
# Epoch 22/50, Loss: 0.23847799880996995
# Epoch 23/50, Loss: 0.2347483588301617
# Epoch 24/50, Loss: 0.2303024813208891
# Epoch 25/50, Loss: 0.21508238799870014
# Epoch 26/50, Loss: 0.208614589387308
# Epoch 27/50, Loss: 0.19836309422617374
# Epoch 28/50, Loss: 0.19214513523747093
# Epoch 29/50, Loss: 0.19468375131811785
# Epoch 30/50, Loss: 0.1995041303984497
# Epoch 31/50, Loss: 0.18830198632634204
# Epoch 32/50, Loss: 0.1757705381868974
# Epoch 33/50, Loss: 0.16300929204925246
# Epoch 34/50, Loss: 0.15788003596598688
# Epoch 35/50, Loss: 0.1491558261377656
# Epoch 36/50, Loss: 0.14564846635836623
# Epoch 37/50, Loss: 0.14075702168047427
# Epoch 38/50, Loss: 0.13839584969632004
# Epoch 39/50, Loss: 0.14176424863221854
# Epoch 40/50, Loss: 0.13495005710131447
# Epoch 41/50, Loss: 0.12611639588747336
# Epoch 42/50, Loss: 0.125900972990886
# Epoch 43/50, Loss: 0.12468357930040878
# Epoch 44/50, Loss: 0.1322867258735325
# Epoch 45/50, Loss: 0.12787181696166164
# Epoch 46/50, Loss: 0.12980724513206793
# Epoch 47/50, Loss: 0.12700505140844895
# Epoch 48/50, Loss: 0.12233030115780623
# Epoch 49/50, Loss: 0.12284907915669939
# Epoch 50/50, Loss: 0.11925316458648962

# %% [markdown]
# ## 5. 模型验证

# %%
@torch.no_grad()
def eval(model, dataloader):
    model.eval()
    outputs = []

    for x, y in dataloader:
        output = model(x.to(device)).argmax(dim=-1).view(-1).cpu().tolist()
        outputs.append(
            (
                [index for index in x.view(-1).tolist() if index],
                [index for index in y.view(-1).tolist() if index],
                [index for index in output if index],
            )
        )

    return outputs


for source, target, output in eval(model, DataLoader(test_data)):
    print("source:", " ".join(fra_words[i - 1] for i in source))
    print("target:", " ".join(eng_words[i - 1] for i in target))
    print("output:", " ".join(eng_words[i - 1] for i in output))
    print()
# Out:
# source: qu ' avez - vous fait l à ?
# target: what was it that you did there ?
# output: what did you do this ?
#
# source: nous avons beaucoup de temps .
# target: we have a lot of time .
# output: we have a lot of time .
#
# source: tom a demand é à marie de lire la lettre .
# target: tom asked mary to read the letter .
# output: tom asked to read the book .
#
# source: c ' est mon v é lo .
# target: the bicycle is mine .
# output: this is my bicycle .
#
# source: ne le dites à personne !
# target: don ' t tell anyone .
# output: don ' t tell anybody .
#
# source: je vous ai vue .
# target: i saw you .
# output: i saw you .
#
# source: j ' aurais d û le voir venir .
# target: i should ' ve seen this coming .
# output: i should ' ve gone there .
#
# source: n ' as - tu pas de travail à faire ?
# target: don ' t you have work to do ?
# output: don ' t you have some work to do ?
#
# source: je peux le faire moi - m ê me   !
# target: i can do it by myself !
# output: i can do it myself !
#
# source: vous faites tout ce que vous pouvez .
# target: you ' re doing all you can .
# output: you ' re doing all you can .
#
# source: il y a encore beaucoup à faire .
# target: there ' s still a lot to be done .
# output: there ' s still so much left to do .
#
# source: c ' est moi qui l ' ai fait .
# target: i did it .
# output: i did it .
#
# source: vous avez é t é occup é , non ?
# target: you ' ve been busy , haven ' t you ?
# output: you ' ve been busy , haven ' t you ?
#
# source: je ne connais aucune de ces personnes .
# target: i don ' t know any of those people .
# output: i don ' t know any more money .
#
# source: je vais à cet endroit .
# target: i am going to that place .
# output: i ' m here with you .
#
# source: c ' est la v é rit é .
# target: it ' s the truth .
# output: you ' d better believe it .
#
# source: j ' ignore le chemin .
# target: i don ' t know the way .
# output: i don ' t know it .
#
# source: je ne t ' ai pas vue .
# target: i didn ' t see you .
# output: i didn ' t see you .
#
# source: montre - moi comment le faire !
# target: show me how to do this .
# output: show me how to do that .
#
# source: à table   !
# target: it ' s time to eat .
# output: watch by yourself .
#
# source: tom n ' avait pas à faire ceci .
# target: tom didn ' t have to do this .
# output: tom didn ' t have to do this .
#
# source: ne devrais - tu pas te rendre chez toi ?
# target: shouldn ' t you go home ?
# output: shouldn ' t you go home ?
#
# source: il devrait arriver .
# target: he will come .
# output: he should come .
#
# source: comment il va ?
# target: how are you ?
# output: how is he ?
#
# source: ê tes - vous pr ê tes maintenant ?
# target: are you ready now ?
# output: are you ready now ?
#
# source: je suis vraiment fatigu é .
# target: i ' m really tired .
# output: i ' m really tired .
#
# source: ce n ' est pas encore termin é .
# target: it ' s not over yet .
# output: it ' s not yet .
#
# source: sais - tu ce qu ' il a dit ?
# target: do you know what he said ?
# output: do you know what he said ?
#
# source: tout le monde t ' appr é cie .
# target: everybody likes you .
# output: everyone likes you .
#
# source: o ù as - tu entendu cette histoire ?
# target: where did you hear that story ?
# output: where did you hear that story ?
#
# source: je ne comprends pas pourquoi vous la voulez .
# target: i don ' t understand why you want it .
# output: i don ' t understand why you want it .
#
# source: pouvez - vous nous en faire part ?
# target: can you tell us about it ?
# output: can you tell us a little ?
